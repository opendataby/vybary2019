# %%
import pandas as pd
pd.__version__
# Out:
# '0.23.4'

# %%
cdf = pd.read_csv('dataset/candidates.csv')
cdf.head()
# Out:
#    region#                                         url  \
# 0        1  http://vybary2019.by/candidates/001-1.html
# 1        1  http://vybary2019.by/candidates/001-2.html
# 2        2  http://vybary2019.by/candidates/002-1.html
# 3        2  http://vybary2019.by/candidates/002-2.html
# 4        2  http://vybary2019.by/candidates/002-3.html
#
#                                 name  birth_year  \
# 0        БРИЧ \r\nЛеонид Григорьевич        1958
# 1  КУРИЛОВИЧ \r\nВладимир Георгиевич        1981
# 2        ВАСЬКО\r\nМарина Викторовна        1975
# 3     МАРЧЕНКО\r\nДмитрий Евгеньевич        1970
# 4     ОМЕЛЬЯНЧУК\r\nИрина Николаевна        1960
#
#                                                  job  \
# 0  депутат Палаты представителей Национального со...
# 1                      директор ООО «Строймир Запад»
# 2  заместитель директора по учебной работе ГУО «Г...
# 3                          пенсионер по инвалидности
# 4                    инженер ОАО «Стройгаз г. Брест»
#
# ...

# %%
candidates_total = len(cdf)
candidates_total
# Out:
# 519

# %%
#millenials = cdf[(cdf["3"]>1980) & (cdf["3"]<1996)]
millenials = cdf.query('birth_year>1980 and birth_year<1996')
len(millenials)
# Out:
# 146

# %%
genz = cdf[cdf.birth_year>1995]
len(genz)
# Out:
# 12

# %%
genz
# Out:
#      region#                                         url  \
# 12         3  http://vybary2019.by/candidates/003-5.html
# 50        12  http://vybary2019.by/candidates/012-4.html
# 275       62  http://vybary2019.by/candidates/062-3.html
# 320       74  http://vybary2019.by/candidates/074-3.html
# 424       95  http://vybary2019.by/candidates/095-2.html
# 442       98  http://vybary2019.by/candidates/098-1.html
# 445       98  http://vybary2019.by/candidates/098-4.html
# 462      101  http://vybary2019.by/candidates/101-3.html
# 479      104  http://vybary2019.by/candidates/104-2.html
# 484      105  http://vybary2019.by/candidates/105-1.html
# 506      108  http://vybary2019.by/candidates/108-4.html
# 513      110  http://vybary2019.by/candidates/110-2.html
#
#                                             name  birth_year  \
# 12              ЛЫСЕНКО\r\nСветлана Владимировна        1996
# 50                  КУРАШИК\r\nАндрей Викторович        1997
# ...

# %%
hist = cdf.hist(orientation='horizontal')
